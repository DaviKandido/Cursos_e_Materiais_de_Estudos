# %% [markdown]
# # Projeto 02
#
# Passo a passo do problema
#
# - Buscar as informações da ação automaticamente
# - Criar as analises solicitadas
#     - Cotação maxima
#     - Cotação minima
#     - Valor médio
# - Enviar um e-mail automaticamente para o gestor

# %% [markdown]
# #### Buscar dados da ação automaticamente
#
# Bibliotecas: `yfinance` e `matplotlib`
#
# `!pip install yfinance`  `!pip install matplotlib`

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.2.41)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2.0.1)
# Requirement already satisfied: requests>=2.31 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (5.2.2)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31->yfinance) (2024.7.4)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Cliente\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\cliente\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Cliente\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# importando a yfinance
import yfinance

# %%
# Ex: PETR4.SA (Petrobras), BBAS3.SA (Banco do Brasil)

ticker = input("Digite o código da ação desejada")


dados = yfinance.Ticker(ticker).history(start="2020-01-01", end="2020-12-31")

# Acessar a coluna de fechamento(Close)
fechamento = dados.Close

# Cria um gráfico de linhas com os dados de fechamento
grafico = fechamento.plot()

# %% [markdown]
# #### Criar as Analises Solicitadas
#
# - Cotação máxima
# - Cotação mínima
# - Valor média

# %%
# Seleciona o valor máximo da tabela
maxima = fechamento.max()

# Seleciona o valor mínimo da tabela
minima = fechamento.min()

# Seleciona o valor médio da tabela
valor_medio = fechamento.mean()

print(maxima)
print(minima)
print(valor_medio)
print()

# Arredonda para o inteiro mais proximo
print(round(10.65))

# Arredonda para o numero com duas casas decimais mais proximo
print(round(10.657, 2))


maxima = round(fechamento.max(), 2)

minima = round(fechamento.min(), 2)

valor_medio = round(fechamento.mean(), 2)

print()
print(maxima)
print(minima)
print(valor_medio)
# Out:
# 10.962862014770508
# 4.017225742340088
# 7.936211947471865
#
# 11
# 10.66
#
# 10.96
# 4.02
# 7.94

# %% [markdown]
# #### Enviar o e-mail automaticamente
#
# - abrir o navegador e ir para o gmail
# - clicar no botão Escrever
# - digitar o endereço de e-mail do destinatário e teclar TAB
# - digitar o assunto do email e teclar TAB
# - Digitar a mensagem
# - Clicar no botão Enviar
#
# Bibliotecas: `pyautogui`, `pyperclip`, `webbroser`
#
# `pip install pyautogui`

# %% [markdown]
# #### Bibliotecas

# %%
# Permite manipular/automatizar o mouse
import pyautogui

# Permite manipular/automatizar comandos de teclado como ctrl c, v TAB etc.
import pyperclip

# Biblioteca que permite manipular o navegador
import webbrowser

# Biblioteca que permite add tempo de espera no código
import time

destinatario = "sppirlog@gmail.com"
Assunto = "Análises do Projeto 2020"


# """ (3 aspas) permite quebrar linha
mensagem = f"""
Estou criando um projeto de automação de envio de analise de dados em python: 

Prezado gestor,
Seguem as análises solicitadas da ação {ticker}:

cotação máxima: R${maxima}
cotação mínima: R${minima}
cotação média: R${valor_medio}

Qualquer dúvida estou a disposição!


atte.
"""

# abrir o navegador e ir para o gmail
webbrowser.open("WWW.gmail.com")
# Espera 3 segundo para executar os próximos códigos
time.sleep(3)

# Configurando uma pausa de 3 seg no pyautogui
pyautogui.PAUSE = 1

# Clicar no botão escrever
pyautogui.click(x=-1605, y=489)


#Digitar o email do destinatário e teclar TAB
pyperclip.copy(destinatario)

# Add de atalhos a serem executados
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("tab")

# Digitar o assunto do email
pyperclip.copy(Assunto)

pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("tab")

# Digitar a mensagem
pyperclip.copy(mensagem)

pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("tab")


# click no botão de enviar

pyautogui.click(x=-669, y=1060)

# %%
# Ao executar permite mostrar a posição do mouse
# Ex: Point(x=1724, y=967)
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=-669, y=1060)
